# %%
import csv
import matplotlib.pyplot as plt

Lines=[]
filename='trees.csv'
with open (filename,newline='') as csvfile:
    csvreader=csv.reader(csvfile)

# Extraire l’ensemble des lignes (rows) et stocker ces informations dans une variable de type List
    for row in csvreader:
        Lines.append(row)
    
# Afficher les deux premières lignes de ce csv. Que représentent elles ?
print(Lines[0],"\n",Lines[1])

# Afficher la 2ème colonne de chacune de ces deux lignes.
i=0
while (i<=1):
    print(Lines[i][1])
    i+=1

# Extraire l’information concernant l’année de plantation pour l’ensemble des lignes (rows) et stocker ces informations dans une autre variable de type List

j=0 #column counter
i=1 #lines counter
header=Lines[0]
anne_arbre=[]
for column in header:
    
    if column=="ANNEEDEPLANTATION":
            while (i<len(Lines)):
                print(Lines[i][j])
                anne_arbre.append(Lines[i][j])
                i+=1
    j+=1

#Afficher les 50 premières lignes et les 50 dernières lignes de cette liste.
k=0
l_50=len(Lines)-50
while (k<50 or (k>=l_50 and k<len(Lines))):
    for l50 in Lines[k]:
            print(l50)
    k+=1
            
    if(k==50):
         k= l_50
print("\n")
#Combien d’arbres sont recensés dans ce jeu de données ?
arbre_recense=len(Lines)
print(arbre_recense)

#Pour combien d’arbres manque-t-il l’information concernant la date de plantation ? (Vous pouvez essayer de le faire d’au moins deux manières différentes.)
print("\n")
print(anne_arbre)
anne_arbre_sans_vide=[]
        # Methode 1
anne_arbre_sans_vide=[element for element in anne_arbre if element]
print(anne_arbre_sans_vide)
arbre_sans_date=len(anne_arbre)-len(anne_arbre_sans_vide)
print(arbre_sans_date)
print("\n")
        # Methode 2
anne_arbre_sans_2_methode=[]
for v in anne_arbre:
     if v!="":
          anne_arbre_sans_2_methode.append(v)
print(anne_arbre_sans_2_methode)
print(len(anne_arbre)-len(anne_arbre_sans_2_methode))

#Combien d’arbres ont été plantés l’année de votre naissance ?
nbre_ma_naissance=0
for v in anne_arbre:
     if v=="1991":
          nbre_ma_naissance+=1

print(nbre_ma_naissance)
print("\n")

#Quelle est la plus ancienne année de plantation recensée dans ce dataset ? La plus récente ?
anne_arbre_sans_vide_entier=[]
for i in anne_arbre_sans_vide:
     anne_arbre_sans_vide_entier.append(int(i))

print(anne_arbre_sans_vide_entier)

ancienne_annee_plantation=anne_arbre_sans_vide_entier[0]
for i in anne_arbre_sans_vide_entier:    
    if(i < ancienne_annee_plantation):
        ancienne_annee_plantation= i

print(ancienne_annee_plantation)
print("\n")
Recent_annee_plantation=anne_arbre_sans_vide_entier[0]
for i in anne_arbre_sans_vide_entier:    
    if(i < Recent_annee_plantation):
        ancienne_annee_plantation= i

print(Recent_annee_plantation)
print("\n")

#Combien d’arbres ont été plantés année par année (ex : 1987 : 771, 1988 :266, etc...) ?
count=anne_arbre_sans_vide_entier.count(2017)
print("count 2017",count)
dictionnaire={}

for i in anne_arbre_sans_vide_entier:
    dictionnaire[i]= anne_arbre_sans_vide_entier.count(i)   

print(dictionnaire)

s=0
i=0
for key in dictionnaire:
     s+=dictionnaire[key]
     i+=1

average=s/i

print(average)
myList = dictionnaire.items()
print(myList)
myList = sorted(myList)
print(myList)
x, y = zip(*myList)
plt.plot(x, y)
# Out:
# ['\ufeffELEM_POINT_ID', 'CODE', 'NOM', 'GENRE', 'GENRE_DESC', 'CATEGORIE', 'CATEGORIE_DESC', 'SOUS_CATEGORIE', 'SOUS_CATEGORIE_DESC', 'CODE_PARENT', 'CODE_PARENT_DESC', 'ADR_SECTEUR', 'BIEN_REFERENCE', 'GENRE_BOTA', 'ESPECE', 'VARIETE', 'STADEDEDEVELOPPEMENT', 'EQUIPE', 'REMARQUES', 'ANNEEDEPLANTATION', 'RAISONDEPLANTATION', 'TRAITEMENTCHENILLES', 'COURRIER', 'IDENTIFIANTPLU', 'TYPEIMPLANTATIONPLU', 'INTITULEPROTECTIONPLU', 'ANNEEABATTAGE', 'ESSOUCHEMENT', 'DIAMETREARBRE', 'CAUSEABATTAGE', 'COLLECTIVITE', 'GeoJSON']
#  ['37993', 'ESP37969', 'ESP37969', 'VEG', 'VEGETATION', 'ESP01', 'Arbre', 'ESP065', "Arbre d'enceintes fermées", 'ESP37898', 'Maison des Collines Jard Poisat', '6', 'AR37969', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '{"type":"Point","coordinates":[5.76034690089422,45.1543159441061]}']
# CODE
# ESP37969
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# 2017
# ...
